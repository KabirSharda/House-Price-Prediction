# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train = pd.read_csv('dataset/train.csv')

# %%
test = pd.read_csv('dataset/test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
price = pd.concat([train,test], ignore_index = True)

# %%
price.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
price.iloc[1461, :]
# Out:
# Id                 1462
# MSSubClass           20
# MSZoning             RL
# LotFrontage        81.0
# LotArea           14267
#                   ...
# MoSold                6
# YrSold             2010
# SaleType             WD
# SaleCondition    Normal
# SalePrice           NaN
# Name: 1461, Length: 81, dtype: object

# %%
price['SalePrice'].fillna(0, inplace = True)

# %%
price.iloc[1461, :]
# Out:
# Id                 1462
# MSSubClass           20
# MSZoning             RL
# LotFrontage        81.0
# LotArea           14267
#                   ...
# MoSold                6
# YrSold             2010
# SaleType             WD
# SaleCondition    Normal
# SalePrice           0.0
# Name: 1461, Length: 81, dtype: object

# %%
nulltest = pd.DataFrame(test.isna().sum())
nulltest
# Out:
#                  0
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage    227
# LotArea          0
# ...            ...
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
#
# [80 rows x 1 columns]

# %%
nulltest.rename(columns = {0:'No. of null values'}, inplace = True)

# %%
nulltrain = pd.DataFrame(train.isna().sum())
nulltrain.rename(columns = {0:'No. of null values'}, inplace = True)

# %%
nulltest[nulltest['No. of null values'] > 0]
# Out:
#               No. of null values
# MSZoning                       4
# LotFrontage                  227
# Alley                       1352
# Utilities                      2
# Exterior1st                    1
# Exterior2nd                    1
# MasVnrType                    16
# MasVnrArea                    15
# BsmtQual                      44
# BsmtCond                      45
# BsmtExposure                  44
# BsmtFinType1                  42
# BsmtFinSF1                     1
# BsmtFinType2                  42
# BsmtFinSF2                     1
# BsmtUnfSF                      1
# TotalBsmtSF                    1
# BsmtFullBath                   2
# BsmtHalfBath                   2
# KitchenQual                    1
# Functional                     2
# FireplaceQu                  730
# GarageType                    76
# GarageYrBlt                   78
# GarageFinish                  78
# GarageCars                     1
# GarageArea                     1
# ...

# %%
nulltest[nulltest['No. of null values'] > 0].shape
# Out:
# (33, 1)

# %%
nulltrain[nulltrain['No. of null values'] > 0]
# Out:
#               No. of null values
# LotFrontage                  259
# Alley                       1369
# MasVnrType                     8
# MasVnrArea                     8
# BsmtQual                      37
# BsmtCond                      37
# BsmtExposure                  38
# BsmtFinType1                  37
# BsmtFinType2                  38
# Electrical                     1
# FireplaceQu                  690
# GarageType                    81
# GarageYrBlt                   81
# GarageFinish                  81
# GarageQual                    81
# GarageCond                    81
# PoolQC                      1453
# Fence                       1179
# MiscFeature                 1406

# %%
nulltrain[nulltrain['No. of null values'] > 0].shape
# Out:
# (19, 1)

# %%
price['MSSubClass'].value_counts()
# Out:
# 20     1079
# 60      575
# 50      287
# 120     182
# 30      139
# 70      128
# 160     128
# 80      118
# 90      109
# 190      61
# 85       48
# 75       23
# 45       18
# 180      17
# 40        6
# 150       1
# Name: MSSubClass, dtype: int64

# %%
sns.boxplot(data=train, x='MSSubClass', y ='SalePrice')
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %%
train.GarageCars == 4
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: GarageCars, Length: 1460, dtype: bool

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.dtypes == ('object')
# Out:
# Id               False
# MSSubClass       False
# MSZoning          True
# LotFrontage      False
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType          True
# SaleCondition     True
# SalePrice        False
# Length: 81, dtype: bool

# %%
cat_train = train.loc[:,train.dtypes == 'object'].columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
num_train = train.loc[:,((train.dtypes == int) | (train.dtypes == float))].columns

# %%
null_train = pd.DataFrame(train.isna().sum())
null_train
null_train[null_train[0] > 0]
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %%
train_pool = train[train['PoolArea'] == 0]

# %%
train_pool['PoolQC'] = 'NA'
train_pool['PoolQC'].isna().sum()
# Out:
# <ipython-input-658-791d17afcd9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_pool['PoolQC'] = 'NA'
# 0

# %%
null_train = pd.DataFrame(train.isna().sum())
null_train
null_train[null_train[0] > 0]
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC        1453
# Fence         1179
# MiscFeature   1406

# %%
train['PoolQC'] = train['PoolQC'].loc[train.PoolArea == 0].apply(lambda x: 0)

# %%
null_train = pd.DataFrame(train.isna().sum())
null_train
null_train[null_train[0] > 0]
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC           7
# Fence         1179
# MiscFeature   1406

# %%
train.EnclosedPorch.value_counts()
# Out:
# 0      1252
# 112      15
# 96        6
# 120       5
# 192       5
#        ...
# 170       1
# 169       1
# 67        1
# 68        1
# 552       1
# Name: EnclosedPorch, Length: 120, dtype: int64

# %%
train.WoodDeckSF.value_counts()
# Out:
# 0      761
# 192     38
# 100     36
# 144     33
# 120     31
#       ...
# 103      1
# 269      1
# 98       1
# 97       1
# 857      1
# Name: WoodDeckSF, Length: 274, dtype: int64

# %%
train.MiscVal.value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 480         2
# 1200        2
# 2500        1
# 350         1
# 560         1
# 54          1
# 620         1
# 8300        1
# 800         1
# 1150        1
# 15500       1
# 1300        1
# 1400        1
# 3500        1
# Name: MiscVal, dtype: int64

# %%
train.Electrical.fillna('SBrkr', inplace = True)

# %%
null_train = pd.DataFrame(train.isna().sum())
null_train
null_train[null_train[0] > 0]
# Out:
#                  0
# LotFrontage    259
# Alley         1369
# MasVnrType       8
# MasVnrArea       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# FireplaceQu    690
# GarageType      81
# GarageYrBlt     81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# PoolQC           7
# Fence         1179
# MiscFeature   1406

# %%
train[train.Electrical.isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
train.Electrical.mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
sns.lmplot(data = train, x = 'LotArea', y = 'LotFrontage')

# %%
remaining_area = train['LotArea'] - train['GrLivArea']

# %%
lotFrontage_conditions = [['MSZoning','LotShape','LotConfig','LandContour']]

# %%
train.groupby('MSSubClass')['LotFrontage'].median().to_frame()
# Out:
#             LotFrontage
# MSSubClass
# 20                 75.0
# 30                 59.0
# 40                 50.0
# 45                 55.0
# 50                 60.0
# 60                 77.5
# 70                 60.0
# 75                 65.0
# 80                 80.0
# 85                 70.0
# 90                 70.0
# 120                44.0
# 160                24.0
# 180                21.0
# 190                60.0

# %%
train.groupby('LotShape')['LotFrontage'].median().to_frame()
# Out:
#           LotFrontage
# LotShape
# IR1              74.0
# IR2              57.5
# IR3             150.0
# Reg              67.0

# %%
train.groupby('LotConfig')['LotFrontage'].median().to_frame()
# Out:
#            LotFrontage
# LotConfig
# Corner            80.0
# CulDSac           50.0
# FR2               64.0
# FR3               59.5
# Inside            68.0

# %%
train.groupby('LotConfig')['LotFrontage'].mean().to_frame()
# Out:
#            LotFrontage
# LotConfig
# Corner       84.039801
# CulDSac      59.911111
# FR2          63.515152
# FR3          70.750000
# Inside       67.715686

# %%
train.groupby('LandContour')['LotFrontage'].median().to_frame()
# Out:
#              LotFrontage
# LandContour
# Bnk                 62.0
# HLS                 70.5
# Low                 79.0
# Lvl                 70.0

# %%
train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
sum1 = 0
sum2 = 0
for i in cat_train:
    sum1 = sum1+ train[i].nunique()
    sum2 = sum2 + test[i].nunique()
print(sum1)
print(sum2)
# Out:
# 250
# 234

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.drop(columns = ['Street', 'Alley', 'Utilities', 'RoofMatl', 'LandSlope', 'Condition1', 'Condition2'], inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearBuilt      1460 non-null   int64
#  14  YearRemodAdd   1460 non-null   int64
#  15  RoofStyle      1460 non-null   object
#  16  Exterior1st    1460 non-null   object
# ...

# %%
train['MiscVal'].value_counts()
# Out:
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 480         2
# 1200        2
# 2500        1
# 350         1
# 560         1
# 54          1
# 620         1
# 8300        1
# 800         1
# 1150        1
# 15500       1
# 1300        1
# 1400        1
# 3500        1
# Name: MiscVal, dtype: int64

# %%
sns.barplot(data= train, x = 'SaleType', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='SaleType', ylabel='SalePrice'>

# %%
num_train
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearBuilt      1460 non-null   int64
#  14  YearRemodAdd   1460 non-null   int64
#  15  RoofStyle      1460 non-null   object
#  16  Exterior1st    1460 non-null   object
# ...

# %%
train.LotFrontage.isna().sum()
# Out:
# 259

# %%
train.groupby(['Neighborhood','LotConfig'])['LotFrontage'].median().to_frame().head(20)
# Out:
#                         LotFrontage
# Neighborhood LotConfig
# Blmngtn      Inside            43.0
# Blueste      Inside            24.0
# BrDale       Inside            21.0
# BrkSide      Corner            51.0
#              FR2               60.0
#              FR3               60.0
#              Inside            52.0
# ClearCr      Corner            89.0
#              CulDSac           73.0
#              Inside            80.0
# CollgCr      Corner            89.0
#              CulDSac           48.0
#              FR2               63.0
#              Inside            69.0
# Crawfor      Corner            57.5
#              CulDSac            NaN
#              FR2               54.0
#              Inside            75.0
# Edwards      Corner            75.0
#              CulDSac           35.0

# %%
train['LotFrontage'] = train['LotFrontage'].fillna(train.groupby(['Neighborhood','LotConfig'])['LotFrontage'].transform(lambda x: x.median()))

# %%
train.LotFrontage.isna().sum()
# Out:
# 5

# %%
train.LotFrontage.fillna(train.LotFrontage.median(), inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearBuilt      1460 non-null   int64
#  14  YearRemodAdd   1460 non-null   int64
#  15  RoofStyle      1460 non-null   object
#  16  Exterior1st    1460 non-null   object
# ...

# %%
train.drop(columns = 'GarageYrBlt', inplace = True)

# %%
train.drop(columns = 'MiscFeature', inplace = True)

# %%
train.drop(columns = 'PoolQC', inplace = True)

# %%
train.MasVnrArea.fillna(train.MasVnrArea.median(), inplace = True)

# %%
train_area = train[['LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','GrLivArea','GarageArea','WoodDeckSF','1stFlrSF','2ndFlrSF','LowQualFinSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea']]

# %%
train_area.corr()
# Out:
#                 LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# LotArea        1.000000    0.103321    0.214103    0.111170  -0.002618
# MasVnrArea     0.103321    1.000000    0.261256   -0.071330   0.113862
# BsmtFinSF1     0.214103    0.261256    1.000000   -0.050117  -0.495251
# BsmtFinSF2     0.111170   -0.071330   -0.050117    1.000000  -0.209294
# BsmtUnfSF     -0.002618    0.113862   -0.495251   -0.209294   1.000000
# TotalBsmtSF    0.260833    0.360067    0.522396    0.104810   0.415360
# GrLivArea      0.263116    0.388052    0.208171   -0.009640   0.240257
# GarageArea     0.180403    0.370884    0.296970   -0.018227   0.183303
# WoodDeckSF     0.171698    0.159991    0.204306    0.067898  -0.005316
# 1stFlrSF       0.299475    0.339850    0.445863    0.097117   0.317987
# 2ndFlrSF       0.050986    0.173800   -0.137079   -0.099260   0.004469
# LowQualFinSF   0.004779   -0.068628   -0.064503    0.014807   0.028167
# ...

# %%
plt.figure(figsize = (20,20))
sns.heatmap(train_area.corr(), annot = True, vmin = -1)
for i in train_area.columns:
    for j in train_area.columns:
        if ((train_area[i].corr(train_area[j]) > 0.5) & (i != j)):
            print(i,j,train_area[i].corr(train_area[j]))
# Out:
# BsmtFinSF1 TotalBsmtSF 0.5223960519923858
# TotalBsmtSF BsmtFinSF1 0.5223960519923858
# TotalBsmtSF 1stFlrSF 0.8195299750050337
# GrLivArea 1stFlrSF 0.5660239689357487
# GrLivArea 2ndFlrSF 0.6875010641666043
# 1stFlrSF TotalBsmtSF 0.8195299750050337
# 1stFlrSF GrLivArea 0.5660239689357487
# 2ndFlrSF GrLivArea 0.6875010641666042

# %%
train.drop(columns = ['TotalBsmtSF','GrLivArea'], inplace = True)

# %%
train['Age'] = train['YrSold'] - train['YearBuilt']

# %%
train.drop(columns = ['YrSold','YearBuilt'], inplace = True)

# %%
quant = [f for f in train.columns if train.dtypes[f] != 'object']
quant.remove('SalePrice')
quant.remove('Id')
corr_matrix = train[quant + ['SalePrice']].corr()

# %%
fig, ax = plt.subplots(figsize=(9,9))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, center=0, cmap="PRGn", annot = True)
for i in train[quant].columns:
    for j in train[quant].columns:
        if ((train[i].corr(train[j]) > 0.5) & (i != j)):
            print(i,j,train[i].corr(train[j]))
# Out:
# OverallQual YearRemodAdd 0.5506839241941723
# OverallQual FullBath 0.550599709368252
# OverallQual GarageCars 0.6006707165907152
# OverallQual GarageArea 0.5620217566126077
# YearRemodAdd OverallQual 0.5506839241941722
# BsmtFinSF1 BsmtFullBath 0.6492117535742645
# 2ndFlrSF HalfBath 0.6097073002717454
# 2ndFlrSF BedroomAbvGr 0.5029006133459057
# 2ndFlrSF TotRmsAbvGrd 0.6164226354915439
# BsmtFullBath BsmtFinSF1 0.6492117535742645
# FullBath OverallQual 0.550599709368252
# FullBath TotRmsAbvGrd 0.554784253533483
# HalfBath 2ndFlrSF 0.6097073002717452
# BedroomAbvGr 2ndFlrSF 0.5029006133459057
# BedroomAbvGr TotRmsAbvGrd 0.6766199357426488
# TotRmsAbvGrd 2ndFlrSF 0.6164226354915439
# TotRmsAbvGrd FullBath 0.554784253533483
# TotRmsAbvGrd BedroomAbvGr 0.6766199357426488
# GarageCars OverallQual 0.6006707165907151
# GarageCars GarageArea 0.8824754142814625
# GarageArea OverallQual 0.5620217566126076
# GarageArea GarageCars 0.8824754142814625

# %%
sns.heatmap(corr_matrix, vmin=-1, vmax=1, center=0, cmap="PRGn", annot = True)
# Out:
# <AxesSubplot:>

# %%
for i in train[quant]:
    print(i,train[i].corr(train['SalePrice']))
# Out:
# MSSubClass -0.08428413512659531
# LotFrontage 0.3404697476690788
# LotArea 0.2638433538714056
# OverallQual 0.7909816005838044
# OverallCond -0.07785589404867803
# YearRemodAdd 0.5071009671113865
# MasVnrArea 0.47261449900457475
# BsmtFinSF1 0.3864198062421532
# BsmtFinSF2 -0.011378121450215125
# BsmtUnfSF 0.21447910554696892
# 1stFlrSF 0.6058521846919147
# 2ndFlrSF 0.3193338028320681
# LowQualFinSF -0.02560613000067959
# BsmtFullBath 0.22712223313149382
# BsmtHalfBath -0.016844154297359016
# FullBath 0.5606637627484449
# HalfBath 0.2841076755947831
# BedroomAbvGr 0.16821315430073988
# KitchenAbvGr -0.13590737084214122
# TotRmsAbvGrd 0.5337231555820282
# Fireplaces 0.46692883675152724
# GarageCars 0.6404091972583529
# GarageArea 0.6234314389183618
# WoodDeckSF 0.3244134445681294
# OpenPorchSF 0.3158562271160555
# EnclosedPorch -0.12857795792595653
# 3SsnPorch 0.04458366533574846
# ScreenPorch 0.11144657114291105
# PoolArea 0.09240354949187321
# MiscVal -0.02118957964030325
# ...

# %%
train.drop(columns = ['BedroomAbvGr','TotRmsAbvGrd'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearRemodAdd   1460 non-null   int64
#  14  RoofStyle      1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
train.MasVnrType.fillna(train.MasVnrType.mode(),inplace = True)
train.FireplaceQu.fillna('NoFireplace',inplace = True)
train.GarageQual.fillna('No Garage',inplace = True)
train.GarageCond.fillna('No Garage',inplace = True)
train.GarageType.fillna('No Garage',inplace = True)
train['GarageFinish'].fillna('NoGarage', inplace=True)
train['BsmtFinType2'].fillna('NoBsmt', inplace=True)
train['BsmtExposure'].fillna('NoBsmt', inplace=True)
train['BsmtCond'].fillna('NoBsmt', inplace=True)
train['BsmtFinType1'].fillna('NoBsmt', inplace=True)
train['BsmtQual'].fillna('NoBsmt', inplace=True)
train['MasVnrType'].fillna('NoMas', inplace=True)


train.drop(columns = ['Fence'], inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearRemodAdd   1460 non-null   int64
#  14  RoofStyle      1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
test.drop(columns = ['Street', 'Alley', 'Utilities', 'RoofMatl', 'LandSlope', 'Condition1', 'Condition2'], inplace=True)

test.drop(columns = 'GarageYrBlt', inplace = True)
test.drop(columns = 'MiscFeature', inplace = True)
test.drop(columns = 'PoolQC', inplace = True)
test.MasVnrArea.fillna(train.MasVnrArea.median(), inplace = True)
test.drop(columns = ['TotalBsmtSF','GrLivArea'], inplace = True)
test['Age'] = test['YrSold'] - test['YearBuilt']
test.drop(columns = ['YrSold','YearBuilt'], inplace = True)
test.drop(columns = ['BedroomAbvGr','TotRmsAbvGrd'], inplace = True)
test.MasVnrType.fillna(train.MasVnrType.mode(),inplace = True)
test.FireplaceQu.fillna('NoFireplace',inplace = True)
test.GarageQual.fillna('No Garage',inplace = True)
test.GarageCond.fillna('No Garage',inplace = True)
test.GarageType.fillna('No Garage',inplace = True)
test['GarageFinish'].fillna('NoGarage', inplace=True)
test['BsmtFinType2'].fillna('NoBsmt', inplace=True)
test['BsmtExposure'].fillna('NoBsmt', inplace=True)
test['BsmtCond'].fillna('NoBsmt', inplace=True)
test['BsmtFinType1'].fillna('NoBsmt', inplace=True)
test['BsmtQual'].fillna('NoBsmt', inplace=True)
test['MasVnrType'].fillna('NoMas', inplace=True)


test.drop(columns = ['Fence'], inplace = True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 64 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   LotShape       1459 non-null   object
#  6   LandContour    1459 non-null   object
#  7   LotConfig      1459 non-null   object
#  8   Neighborhood   1459 non-null   object
#  9   BldgType       1459 non-null   object
#  10  HouseStyle     1459 non-null   object
#  11  OverallQual    1459 non-null   int64
#  12  OverallCond    1459 non-null   int64
#  13  YearRemodAdd   1459 non-null   int64
#  14  RoofStyle      1459 non-null   object
#  15  Exterior1st    1458 non-null   object
#  16  Exterior2nd    1458 non-null   object
# ...

# %%
test.Exterior1st.fillna('NA', inplace = True)
test.Exterior2nd.fillna('NA', inplace = True)
test.BsmtFinSF1.fillna(train.BsmtFinSF1.median(), inplace = True)
test.BsmtFinSF2.fillna(train.BsmtFinSF2.median(), inplace = True)
test.BsmtUnfSF.fillna(train.BsmtUnfSF.median(), inplace = True)
test.BsmtFullBath.fillna(train.BsmtFullBath.median(), inplace = True)
test.BsmtHalfBath.fillna(train.BsmtHalfBath.median(), inplace = True)
test.KitchenQual.fillna('NoKitchen', inplace = True)
test.Functional.fillna('NA', inplace = True)
test.GarageCars.fillna('NoGarage', inplace = True)
test.GarageArea.fillna(train.GarageArea.median(), inplace = True)
test.MSZoning.fillna(train['MSZoning'].mode()[0], inplace = True)
test.SaleType.fillna('NA', inplace = True)

# %%
import scipy.stats

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 64 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   LotShape       1459 non-null   object
#  6   LandContour    1459 non-null   object
#  7   LotConfig      1459 non-null   object
#  8   Neighborhood   1459 non-null   object
#  9   BldgType       1459 non-null   object
#  10  HouseStyle     1459 non-null   object
#  11  OverallQual    1459 non-null   int64
#  12  OverallCond    1459 non-null   int64
#  13  YearRemodAdd   1459 non-null   int64
#  14  RoofStyle      1459 non-null   object
#  15  Exterior1st    1459 non-null   object
#  16  Exterior2nd    1459 non-null   object
# ...

# %%
test['LotFrontage'] = test['LotFrontage'].fillna(test.groupby(['Neighborhood','LotConfig'])['LotFrontage'].transform(lambda x: x.median()))

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 64 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1454 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   LotShape       1459 non-null   object
#  6   LandContour    1459 non-null   object
#  7   LotConfig      1459 non-null   object
#  8   Neighborhood   1459 non-null   object
#  9   BldgType       1459 non-null   object
#  10  HouseStyle     1459 non-null   object
#  11  OverallQual    1459 non-null   int64
#  12  OverallCond    1459 non-null   int64
#  13  YearRemodAdd   1459 non-null   int64
#  14  RoofStyle      1459 non-null   object
#  15  Exterior1st    1459 non-null   object
#  16  Exterior2nd    1459 non-null   object
# ...

# %%
train.LotFrontage.fillna(train.LotFrontage.median(), inplace = True)

# %%
test['SalePrice'] = 0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   Neighborhood   1460 non-null   object
#  9   BldgType       1460 non-null   object
#  10  HouseStyle     1460 non-null   object
#  11  OverallQual    1460 non-null   int64
#  12  OverallCond    1460 non-null   int64
#  13  YearRemodAdd   1460 non-null   int64
#  14  RoofStyle      1460 non-null   object
#  15  Exterior1st    1460 non-null   object
#  16  Exterior2nd    1460 non-null   object
# ...

# %%
all = pd.concat([train,test], ignore_index = True)

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2919 non-null   object
#  3   LotFrontage    2914 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   LotShape       2919 non-null   object
#  6   LandContour    2919 non-null   object
#  7   LotConfig      2919 non-null   object
#  8   Neighborhood   2919 non-null   object
#  9   BldgType       2919 non-null   object
#  10  HouseStyle     2919 non-null   object
#  11  OverallQual    2919 non-null   int64
#  12  OverallCond    2919 non-null   int64
#  13  YearRemodAdd   2919 non-null   int64
#  14  RoofStyle      2919 non-null   object
#  15  Exterior1st    2919 non-null   object
#  16  Exterior2nd    2919 non-null   object
# ...

# %%
all.LotFrontage.fillna(all.LotFrontage.median(), inplace = True)

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2919 non-null   object
#  3   LotFrontage    2919 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   LotShape       2919 non-null   object
#  6   LandContour    2919 non-null   object
#  7   LotConfig      2919 non-null   object
#  8   Neighborhood   2919 non-null   object
#  9   BldgType       2919 non-null   object
#  10  HouseStyle     2919 non-null   object
#  11  OverallQual    2919 non-null   int64
#  12  OverallCond    2919 non-null   int64
#  13  YearRemodAdd   2919 non-null   int64
#  14  RoofStyle      2919 non-null   object
#  15  Exterior1st    2919 non-null   object
#  16  Exterior2nd    2919 non-null   object
# ...
